# %% [markdown]
# # Statistics Advanced - 1| Assignment

# %% [markdown]
# 1. Question 1: What is a random variable in probability theory?
# - A random variable is a variable whose possible values are determined by the outcomes of a random experiment. It assigns a numerical value to each possible outcome of the experiment.
# - There are two main types of random variables:
#      - Discrete Random Variable: Takes on a finite or countable number of possible values.
#         - Example: The number of heads obtained when flipping three coins.
#      - Continuous Random Variable: Takes on an infinite number of possible values within a given range.
#         - Example: The height of students in a class.

# %% [markdown]
# Question 2: What are the types of random variables?
# - There are two main types of random variables in probability theory:
#   - Discrete Random Variable:
#       - It can take only a finite or countable number of distinct values.
#       - These variables are often associated with counting.
#       - Example: Number of students present in a class, number of defective items in a batch.
#   - Continuous Random Variable:
#       - It can take an infinite number of possible values within a certain range or interval.
#       - These variables are associated with measurement.
#       - Example: Height of a person, time taken to finish a task, temperature of a city.

# %% [markdown]
# Question 3: Explain the difference between discrete and continuous distributions.
# - The difference between discrete and continuous distributions lies in the type of random variable they describe and the way probabilities are assigned.
#   - Discrete Distribution:
#       - It deals with discrete random variables that take on a finite or countable number of values.
#       - The probability of each possible value is represented by a probability mass function (PMF).
#       - The sum of all probabilities equals 1.
#       - Example: Binomial distribution, Poisson distribution.
#   - Continuous Distribution:
#       - It deals with continuous random variables that can take on any value within an interval.
#       - Probabilities are described using a probability density function (PDF).
#       - The probability of the variable taking an exact value is 0; instead, probability is measured over a range.
#       - Example: Normal distribution, Exponential distribution

# %% [markdown]
# Question 4: What is a binomial distribution, and how is it used in probability?
#   - A binomial distribution is a type of discrete probability distribution that represents the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes — success or failure.
#     - It is defined by two parameters:
#       - n: Number of trials
#       - p: Probability of success in each trial
#       - The probability of getting exactly k successes in n trials is given by: P(X = k) = (nCk) × p^k × (1 – p)^(n – k)
#
#   - Uses:
#     - It is used to model situations where there are a fixed number of independent yes/no experiments.
#     - Examples:
#       - Number of heads in a series of coin tosses.
#       - Number of defective items in a batch of products.

# %% [markdown]
# Question 5: What is the standard normal distribution, and why is it important?
# - A standard normal distribution is a special case of the normal distribution where the mean (μ) is 0 and the standard deviation (σ) is: It is a continuous probability distribution that is symmetric about the mean and has a bell-shaped curve.
# - The variable that follows this distribution is called a standard normal variable (Z), and it is obtained using the formula:
# Z = (X – μ) / σ
# - Importance:
#   - It simplifies the process of finding probabilities for any normal distribution by converting values to standard form (Z-scores).
#   - It is used to compare data from different normal distributions.
#   - It forms the basis for many statistical tests and confidence interval calculations.

# %% [markdown]
# Question 6: What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#   - The Central Limit Theorem (CLT) states that when independent random samples are taken from any population with a finite mean and variance, the sampling distribution of the sample mean approaches a normal distribution as the sample size becomes large, regardless of the shape of the original population.
#
#   - In simple terms:
#       - As the sample size increases, the distribution of sample means becomes approximately normal, even if the population itself is not normally distributed.
#
#   - Importance:
#
#      - It allows statisticians to use normal probability theory to make inferences about population parameters.
#
#      - It justifies the use of the normal distribution in hypothesis testing and confidence interval estimation.
#
#      - It provides the foundation for many statistical methods used in data analysis.

# %% [markdown]
# Question 7: What is the significance of confidence intervals in statistical analysis?
#   - A confidence interval is a range of values, derived from sample data, that is likely to contain the true population parameter (such as mean or proportion) with a specified level of confidence.
#
#   - For example, a 95% confidence interval means that if we were to take many samples, about 95% of the calculated intervals would contain the true population parameter.
#
#   - Significance:
#
#     - It provides an estimate of uncertainty around a sample statistic.
#
#     - It helps in decision-making by showing the reliability of an estimate.
#
#     - It is more informative than a single point estimate because it gives a range of plausible values.
#
#     - Widely used in hypothesis testing and data interpretation to understand the precision of results.

# %% [markdown]
# Question 8: What is the concept of expected value in a probability distribution?
#   - The expected value of a probability distribution is the weighted average of all possible values that a random variable can take, where each value is weighted by its corresponding probability. It represents the long-term average outcome of a random experiment if it were repeated many times.
#
#   - For a discrete random variable, it is calculated as: E(X) = Σ [x × P(x)]
#
#   - For a continuous random variable, it is given by: E(X) = ∫ x × f(x) dx
#
#   - Interpretation:
#
#     - It gives the measure of the central tendency of a probability distribution.
#
#     - It helps in making predictions and decisions under uncertainty.
#
#     - Example: The expected value of rolling a fair six-sided die is E(X) = (1+2+3+4+5+6)/6 = 3.5

# %% [markdown]
# Question 9: Write a Python program to generate 1000 random numbers from a normal
# distribution with mean = 50 and standard deviation = 5. Compute its mean and standard
# deviation using NumPy, and draw a histogram to visualize the distribution.
#   - np.random.normal() generates random numbers from a normal distribution with specified mean and standard deviation.
#
#   - np.mean() and np.std() compute the sample mean and standard deviation.
#
#   - plt.hist() visualizes the distribution of the generated data.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 1000 random numbers from a normal distribution
mean = 50
std_dev = 5
size = 1000
data = np.random.normal(loc=mean, scale=std_dev, size=size)

# Compute mean and standard deviation
calculated_mean = np.mean(data)
calculated_std = np.std(data)

print("Calculated Mean:", calculated_mean)
print("Calculated Standard Deviation:", calculated_std)

# Draw a histogram
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title("Histogram of Normally Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# Calculated Mean: 49.81120501602719
# Calculated Standard Deviation: 4.932011957013482

# %% [markdown]
# Question 10: You are working as a data analyst for a retail company. The company has collected daily sales data for 2 years and wants you to identify the overall sales trend.
#
#   daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
# 235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
#  - Explain how you would apply the Central Limit Theorem to estimate the average sales
# with a 95% confidence interval.
#  - Write the Python code to compute the mean sales and its confidence interval.

# %%
import numpy as np
from scipy import stats

# Daily sales data
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

# Sample mean and standard deviation
mean_sales = np.mean(daily_sales)
std_sales = np.std(daily_sales, ddof=1)  # ddof=1 for sample std
n = len(daily_sales)

# Standard error
se = std_sales / np.sqrt(n)

# 95% confidence interval using Z-score
z_score = 1.96
ci_lower = mean_sales - z_score * se
ci_upper = mean_sales + z_score * se

print("Mean Daily Sales:", mean_sales)
print("95% Confidence Interval: [{:.2f}, {:.2f}]".format(ci_lower, ci_upper))
# Out:
# Mean Daily Sales: 248.25
# 95% Confidence Interval: [240.68, 255.82]
